# %% [markdown]
# # Data Viz - Milestone 3
#
# ## Nom & Prénom
#
# - Étudiant.e #1
# - Étudiant.e #2

# %% [markdown]
# ## Objectifs d'Apprentissage :
# 1. Sélectionner un type de graphique approprié selon la variable
# 2. Créer une visualisation complète à partir de données réelles
# 3. Appliquer les critères de qualité d'une infographie professionnelle

# %% [markdown]
# ## Instructions :
#
# ### 1. Préparation
# Exécutez les cellules ci-dessous pour installer les bibliothèques nécessaires et charger les données.
#
# ### 2. Sélectionnez vos variables
# Choisissez **1 variable** intéressante dans l'ANES 2024 pour l'analyse de comportements et attitudes politiques.
#
# **Important - Originalité :**
# - Évitez de reprendre exactement les mêmes variables que dans les exemples de cours
# - Essayez de trouver des variables originales qui racontent une histoire intéressante
# - Parcourez le codebook de l'ANES 2024 pour explorer d'autres thématiques
#     - https://sda.berkeley.edu/sdaweb/docs/anes2024full/DOC/hcbkh01.htm
#
# ### 3. Préparez les données
# - Filtrez les observations pertinentes
# - Recodez les valeurs en modalités lisibles
#
# ### 4. Créez votre visualisation
# En vous inspirant des notebooks précédents, créez un graphique avec :
# - un titre explicite
# - un sous-titre avec un exemple de lecture
# - une source
# - une mise en forme adéquate (couleurs, proportions, lisibilité)
#
# ## Critères d'évaluation :
# - Le code fonctionne sans erreur
# - Le graphique est adapté au type de variable sélectionnée
# - Tous les éléments textuels sont présents (titre, sous-titre, source)
# - La mise en forme est soignée
# - Originalité de la variable choisie
#
# ### Format de Rendu :
# - Ce notebook (.ipynb) contenant votre code et visualisation
#
# **Important :**
# Envoyer votre notebook enregistré à l’enseignant.e par email.
#
# Vous pouvez utiliser le modèle suivant pour l'objet de votre email:
#
# > **DECA4 - Rendu 3 - Nom Étudiant 1, Nom Étudiant 2**
#
# Vérifiez que le fichier est correctement nommé et bien joint avant l’envoi de votre mail.

# %% [markdown]
# ## 🎯 ZONE DE TRAVAIL - INSTALLATION ET CHARGEMENT

# %%
# ============================================
# Installation & Importation des bibliothèques
# ============================================
# %pip install "vegafusion[embed]>=1.5.0" "vl-convert-python>=1.6.0"

import pandas as pd
import altair as alt

# Configuration d'Altair
alt.data_transformers.enable("vegafusion")
alt.data_transformers.disable_max_rows()

# Chargement des données
data_url = "https://raw.githubusercontent.com/datamisc/ts-2024/main/data.csv"
df = pd.read_csv(data_url, compression="gzip", low_memory=False)

# %% [markdown]
# ## 💡 CONSEIL pour la sélection de la variable
#
# Consultez le codebook de l’ANES 2024 pour identifier des variables pertinentes (définition, modalités, codage) :
# [https://sda.berkeley.edu/sdaweb/docs/anes2024full/DOC/hcbkh01.htm](https://sda.berkeley.edu/sdaweb/docs/anes2024full/DOC/hcbkh01.htm)
#
# Notez que le [**PDF officiel**](https://electionstudies.org/wp-content/uploads/2025/08/anes_timeseries_2024_userguidecodebook_20250808.pdf) fournit des informations complémentaires, notamment la **formulation exacte des questions**, ce qui peut vous aider à affiner votre interprétation et à formuler d'excellents titres :
# [https://electionstudies.org/wp-content/uploads/2025/08/anes_timeseries_2024_userguidecodebook_20250808.pdf](https://electionstudies.org/wp-content/uploads/2025/08/anes_timeseries_2024_userguidecodebook_20250808.pdf)

# %% [markdown]
# ## 🎯 ZONE DE TRAVAIL - CRÉATION DE LA VISUALISATION
#
# À vous de jouer ! Inspirez-vous des notebooks précédents pour créer votre graphique.

# %%
# ============================================
# SÉLECTION ET PRÉPARATION DE LA VARIABLE
# ============================================

# Inspirez-vous des exemples dans :
# - notebooks/04-exploration-donnees-lignes.ipynb
# - notebooks/05-recodage-creation-variables.ipynb

# Votre code ci-dessous :

# %%
# ============================================
# CRÉATION DU GRAPHIQUE
# ============================================

# Inspirez-vous des exemples dans :
# - notebooks/06-grammaire-graphiques.ipynb
# - notebooks/07-univariee.ipynb

# Votre code ci-dessous :

# %% [markdown]
# ## Analyse et interprétation
#
# ### Vos Réponses :

# %% [markdown]
# **1. Variables sélectionnées :**
# - Variable : [identifiant et description selon le codebook]
# - Pourquoi avez-vous choisi cette variable ?

# %% [markdown]
# **2. Choix du type de visualisation :**
# - Pourquoi ce type de graphique est-il approprié ?
# - Quels défis avez-vous rencontrés dans la préparation ?
