# %% [markdown]
# # Data Viz - Milestone 4
#
# ## Nom & Prénom
#
# - Étudiant.e #1
# - Étudiant.e #2

# %% [markdown]
# ## Objectifs d'Apprentissage :
# 1. Créer une visualisation bivariée avancée avec plusieurs variables
# 2. Utiliser des techniques telles que la **simplification**, le **facet** ou les **couches**
# 3. Produire une visualization complète prête pour le polissage final

# %% [markdown]
# ## Instructions :
#
# ### 1. Préparation
# Exécutez les cellules ci-dessous pour installer les bibliothèques nécessaires et charger les données.
#
# ### 2. Sélectionnez vos variables
#
# Choisissez **au moins 2 variables** intéressantes dans l'ANES 2024 pour l'analyse de comportements et attitudes politiques. Essayez de partir d'une question de recherche intéressante, cela va vous faciliter la tâche.
#
# **Important - Originalité :**
# - Évitez de reprendre exactement les mêmes variables que dans les exemples du cours
# - Essayez de trouver des variables originales qui racontent une histoire intéressante
# - Parcourez le codebook de l'ANES 2024 pour explorer d'autres thématiques
#     - https://sda.berkeley.edu/sdaweb/docs/anes2024full/DOC/hcbkh01.htm
#
# ### 3. Préparez les données
# - Filtrez les observations pertinentes
# - Recodez les valeurs en modalités lisibles
# - Créez des variables dérivées si nécessaire (comme pour la polarisation, le fort intérêt politique, ...)
#
# ### 4. Créez votre visualisation
# En vous inspirant des notebooks 8 et 9, créez un graphique avancé avec :
# - Un **titre explicite**
# - Un **sous-titre** avec un exemple de lecture
# - Une **source**
# - Une **mise en forme** soignée
# - Utilisez une technique avancée : **simplification de variable**, **facet**, **couches**, ou **plusieurs séries**
#
# ### 5. [**BONUS**] Exportez votre graphique
# Utilisez la méthode .save() pour enregistrez votre visualisation dans un format adapté (png, pdf).
#
# ## Critères d'évaluation :
# - Le code fonctionne sans erreur
# - Le graphique utilise au moins 2 variables de manière bivariée
# - Une technique avancée est utilisée (simplification, facet, couches, ou multi-séries)
# - Tous les éléments textuels sont présents (titre, sous-titre, source)
# - La mise en forme est soignée
# - Originalité des variables choisies
#
# ### Format de Rendu :
# - Ce notebook (.ipynb) contenant votre code et votre visualisation
# - BONUS: Le fichier exporté (png/pdf)
#
# **Important :**
# Envoyez votre notebook enregistré à l'enseignant.e par email.
#
# Vous pouvez utiliser le modèle suivant pour l'objet de votre email:
#
# > **DECA4 - Rendu 4 - Nom Étudiant 1, Nom Étudiant 2**
#
# Vérifiez que le fichier est correctement nommé et bien joint avant l'envoi de votre mail.

# %% [markdown]
# ## 🎯 ZONE DE TRAVAIL - INSTALLATION ET CHARGEMENT

# %%
# ============================================
# Installation & Importation des bibliothèques
# ============================================
# %pip install "vegafusion[embed]>=1.5.0" "vl-convert-python>=1.6.0"

import pandas as pd
import altair as alt

# Configuration d'Altair
alt.data_transformers.enable("vegafusion")
alt.data_transformers.disable_max_rows()

# Chargement des données
data_url = "https://raw.githubusercontent.com/datamisc/ts-2024/main/data.csv"
df = pd.read_csv(data_url, compression="gzip", low_memory=False)

# %% [markdown]
# ## 💡 CONSEIL pour la sélection des variables
#
# Consultez le codebook de l'ANES 2024 pour identifier des thématique pertinentes et leurs variables associées :
# [https://sda.berkeley.edu/sdaweb/docs/anes2024full/DOC/hcbkh01.htm](https://sda.berkeley.edu/sdaweb/docs/anes2024full/DOC/hcbkh01.htm)
#
# Le [**PDF officiel**](https://electionstudies.org/wp-content/uploads/2025/08/anes_timeseries_2024_userguidecodebook_20250808.pdf) fournit des informations complémentaires.

# %% [markdown]
# ## 🎯 ZONE DE TRAVAIL
#
# Sélectionnez et préparez vos variables ici.

# %%
# ============================================
# SÉLECTION ET PRÉPARATION DES VARIABLES
# ============================================

# Votre code ci-dessous :

# %% [markdown]
# Créez votre graphique avancé ici. Pensez à utiliser une technique apprise dans le Notebook 8/9 :
# - **Simplification** (variable simplifiées)
# - **Facet**
# - **Couches** (layering)
# - **Plusieurs séries** sur un même graphique

# %%
# ============================================
# CRÉATION DU GRAPHIQUE AVANCÉ
# ============================================

# Votre code ci-dessous :

# %% [markdown]
# ## Analyse et interprétation

# %% [markdown]
# **1. Répondez au trois question ci-dessous:**
# - À quelle question vous permet de répondre votre graphique?
# - Comment interprétez vous les résultats ?
# - Quel est le message de voter graphique ?

# %% [markdown]
# Vos réponse ici:
# ...

# %% [markdown]
# **2. Défis rencontrés :**
# - Quels obstacles avez-vous rencontrés dans la préparation des données ou la création du graphique ?
# - Comment les avez-vous résolus ?

# %% [markdown]
# Votre réponse ici:
# ...
