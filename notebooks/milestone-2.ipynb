# %% [markdown]
# # Data Viz - Milestone 2
#
# ## Nom & Prénom
#
# - Étudiant.e #1
# - Étudiant.e #2

# %% [markdown]
# ## Objectifs d'Apprentissage :
# 1. Explorer différentes variables dans un dataset
# 2. Calculer et interpréter des statistiques descriptives
# 3. Préparer des variables pour la visualisation

# %% [markdown]
# ## Instructions :
#
# ### 1. Préparation
# Exécutez les cellules ci-dessous pour installer les bibliothèques nécessaires et charger les données.
#
# ### 2. Exploration des variables
# Dans le codebook de l'ANES 2024, choisissez **2 variables intéressantes** qui vous semblent pertinentes. Essayez de varier les types de variables (continue, discrète, ordinale,…).
#
# ### 3. Analyse descriptive
# Pour chaque variable sélectionnée :
# - Filtrez les observations pertinentes
# - Calculez les statistiques descriptives appropriées
# - Interprétez brièvement ce que vous observez
#
# ### 4. Questions d'analyse
# - Dans la dernière section, répondez aux questions sur vos découvertes
#
# ## Critères d'évaluation :
# - Le code fonctionne sans erreur
# - Les 2 variables clairement documentées
# - Les statistiques descriptives sont correctes et adaptées au type des variables
# - Les interprétations sont pertinentes
#
# ### Format de Rendu :
# - Ce notebook (.ipynb) contenant votre analyse complète
# - Les réponses aux questions en fin de document
#
# **Important :** Envoyez votre notebook enregistré à l'enseignant.e par email.

# %% [markdown]
# ## 🎯 ZONE DE TRAVAIL - INSTALLATION ET CHARGEMENT

# %%
# ============================================
# Installation & Importation des bibliothèques
# ============================================
import pandas as pd

# Chargement des données
data_url = "https://raw.githubusercontent.com/datamisc/ts-2024/main/data.csv"
df = pd.read_csv(data_url, compression="gzip", low_memory=False)

df.head()

# %% [markdown]
# ## Sélection et analyse des variables
#
# ### Variable 1 - à compléter
# **Identifiant dans le code :** VXXXXXXXX (à remplacer)
#
# **Description selon le codebook :** (à compléter après consultation du codebook)

# %%
# Remplacez 'VXXXXXXXX' par l'identifiant de votre première variable
ma_var_1 = "VXXXXXXXX"  # <--- MODIFIER ICI

# df a déjà été créé dans les blocs de code précédents
df[ma_var_1]

# Utilisez les méthodes/fonctions appropriées pour créer les
# statistiques descriptives appropriées pour la variable choisie

# Mettez votre code ci-dessous

# %% [markdown]
# ### Variable 2 - à compléter
# **Identifiant dans le code :** VXXXXXXXX (à remplacer)
#
# **Description selon le codebook :** (à compléter après consultation du codebook)

# %%
# Remplacez 'VXXXXXXXX' par l'identifiant de votre deuxième variable
ma_var_2 = "VXXXXXXXX"  # <--- MODIFIER ICI

# df a déjà été créé dans les blocs de code précédents
df[ma_var_2]

# Utilisez les méthodes/fonctions appropriées pour créer les
# statistiques descriptives appropriées pour la variable choisie

# Mettez votre code ci-dessous

# %% [markdown]
# ## Analyse et interprétation
#
# ### Vos Réponses :

# %% [markdown]
# **1. Variables sélectionnées et leur pertinence :**
# - Variable 1 : [expliquez pourquoi vous avez choisi cette variable et ce qu'elle mesure]
# - Variable 2 : [expliquez pourquoi vous avez choisi cette variable et ce qu'elle mesure]

# %% [markdown]
# **2. Observations principales :**
# - Quelles tendances principales remarquez-vous dans vos variables ?
# - Y a-t-il des valeurs très fréquentes ou très rares ?

# %% [markdown]
# **3. Réflexion sur l'analyse :**
# - Quelles difficultés avez-vous rencontrées ?
# - Quelles autres analyses aimeriez-vous faire avec ces variables ?
# - Comment ces variables pourraient-elles être utiles pour une analyse politique plus approfondie ?
